# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51880/pds_b14/blob/main/lab_7_pds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
world_population = pd.read_csv("world_population.csv")

# Extract population columns across years
population_cols = [col for col in world_population.columns if "Population" in col and "World" not in col]

# Sum all countries to get world total
pop_data = world_population[population_cols].sum().reset_index()
pop_data.columns = ["Year", "Population"]

# Clean up year column
pop_data["Year"] = pop_data["Year"].str.replace(" Population", "").astype(int)

# Plot world population growth
plt.figure(figsize=(10,6))
plt.plot(pop_data["Year"], pop_data["Population"], marker="o", color="blue", label="World Population")
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("World Population Growth Over Years")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
aapl_stock = pd.read_csv("aapl.csv")

# Convert 'Date' column to datetime
aapl_stock["Date"] = pd.to_datetime(aapl_stock["Date"])

# Plot stock closing prices
plt.figure(figsize=(12,6))
plt.plot(aapl_stock["Date"], aapl_stock["Close"], color="green", label="Apple Close Price")
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("Apple Stock Price Trend")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-645994943.py:8: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   aapl_stock["Date"] = pd.to_datetime(aapl_stock["Date"])
